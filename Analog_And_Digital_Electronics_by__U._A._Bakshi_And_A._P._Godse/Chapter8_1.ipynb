# %% [markdown]
# # Chapter 8

# %% [markdown]
# # Counters

# %% [markdown]
# ## Example 8.1 Page No. 8-1

# %%
print("After 12 pulses,the count will be (1 1 0 0)2, i.e. 12 in decimal.")
# Out:
# After 12 pulses,the count will be (1 1 0 0)2, i.e. 12 in decimal.

# %% [markdown]
# ## Example 8.2 Page No. 8-2

# %%
a = bin (144)
print "decimal (144) =",a
print("Since counter is a 5 bit counter, it resets after 2^5 = 32 clock pulses.")
print("Dividing 144 by 32 we get quotient 2 and remainder 6")
print("Therefore, counter resets four times and then it counts remaining 16 clock pulses. Thus, the count will be binary (1 1 0 0 0 0), i.e., 16 in decimal")
# Out:
# decimal (144) = 0b10010000
# Since counter is a 5 bit counter, it resets after 2^5 = 32 clock pulses.
# Dividing 144 by 32 we get quotient 2 and remainder 6
# Therefore, counter resets four times and then it counts remaining 16 clock pulses. Thus, the count will be binary (1 1 0 0 0 0), i.e., 16 in decimal

# %% [markdown]
# ## Example 8.4 Page No. 8-4

# %%
print("When flip−flops are negatively edge triggered,the Q output of previous stage is connected to the clock input of the next stage. Fig.8.5 shows 3−stage asynchronous counter with negative edge triggered flip−flops.")
# Out:
# When flip−flops are negatively edge triggered,the Q output of previous stage is connected to the clock input of the next stage. Fig.8.5 shows 3−stage asynchronous counter with negative edge triggered flip−flops.

# %% [markdown]
# ## Example 8.5 Page No. 8-4

# %%
of=50.0/14.0
print "Output frequency = 50kHz/14=",round(of,2),"KHz"
# Out:
# Output frequency = 50kHz/14= 3.57 KHz

# %% [markdown]
# ## Example 8.6 Page No. 8-4

# %%
print("We know that MOD−32 uses five flip−flops.With tpd=50ns,the fmax for ripple counter can be given as,")
fm=(1/(250*pow(10,-9)))*pow(10,-6)
print "fmax(ripple)=",fm,"MHz"
# Out:
# We know that MOD−32 uses five flip−flops.With tpd=50ns,the fmax for ripple counter can be given as,
# fmax(ripple)= 4.0 MHz

# %% [markdown]
# ## Example 8.8 Page No. 8-9

# %%
print("The 4−bit counter needs four flip−flops.The circuit for 4−bitup/down ripple counter is similar to 3−bitup/down ripple counter except that 4−bit counter has one more flip−flop and its clock driving circuiting.")
print("The fig.8.14 shows the 4−bit up/down ripple counter.")
# Out:
# The 4−bit counter needs four flip−flops.The circuit for 4−bitup/down ripple counter is similar to 3−bitup/down ripple counter except that 4−bit counter has one more flip−flop and its clock driving circuiting.
# The fig.8.14 shows the 4−bit up/down ripple counter.

# %% [markdown]
# ## Example 8.9 Page No. 8-13

# %%
print("Internal structure of 7492 is as shown in fig.8.16.")
print("")
print("The circuit diagram for divide−by−9counter is as shown in fig.8.17.")
# Out:
# Internal structure of 7492 is as shown in fig.8.16.
#
# The circuit diagram for divide−by−9counter is as shown in fig.8.17.

# %% [markdown]
# ## Example 8.10 Page No. 8-13

# %%
print("Since 128=16x8,a divide−by−16 counter followed by a divide−by−8counter will be come a divide−by−128 counter.IC7493 is a 4−bit binary counter(i.e.mod−16 or divide−by−16),therefore, two IC packages will be required.")
print("The circuit diagram is as shown in fig.8.18.")
# Out:
# Since 128=16x8,a divide−by−16 counter followed by a divide−by−8counter will be come a divide−by−128 counter.IC7493 is a 4−bit binary counter(i.e.mod−16 or divide−by−16),therefore, two IC packages will be required.
# The circuit diagram is as shown in fig.8.18.

# %% [markdown]
# ## Example 8.11 Page No. 8-14

# %%
print("Since 78=13x6,we have to use 7493 as mod−a3 and 7492 as mod−6 counters.For the mod−13 counter QD,QC and QA outputs of 7493 ans ANDed and used to clear the count when the count reaches 1101.For the mod−6 counter,clock is applied to B input of 7492.")
print("The circuit diagram is as shown in the fig.8.19")
# Out:
# Since 78=13x6,we have to use 7493 as mod−a3 and 7492 as mod−6 counters.For the mod−13 counter QD,QC and QA outputs of 7493 ans ANDed and used to clear the count when the count reaches 1101.For the mod−6 counter,clock is applied to B input of 7492.
# The circuit diagram is as shown in the fig.8.19

# %% [markdown]
# ## Example 8.12 Page No. 8-14

# %%
print("The fig.8.20 shows divided−by−6(MOD6) counter using 7493.As shown in the fig.8.20,the clock is applied to inout B of IC7493 and the output count sequence is taken from QD,QCandQB. As soon as count is 110,i.e.QD and QC=1,the internal NAND gate output goes low and it resets the counter.")
# Out:
# The fig.8.20 shows divided−by−6(MOD6) counter using 7493.As shown in the fig.8.20,the clock is applied to inout B of IC7493 and the output count sequence is taken from QD,QCandQB. As soon as count is 110,i.e.QD and QC=1,the internal NAND gate output goes low and it resets the counter.

# %% [markdown]
# ## Example 8.13 Page No. 8-19

# %%
print("For asynchronous counter the total delay that must be allowed between input clock pulses is equal to flip−flop tpd+AND gate tpd.Thus Tclock>=50+20=70ns and so the counter has")
fm=(1/(70*pow(10,-9)))*pow(10,-6)
print "fmax(in MHz)=",round(fm,1),"MHz"
print("We know that MOD−16 ripple counter used four flip−flops. With flip−flop tpd=50ns,the fmax for ripple counter can be given as,")
fma=(1/(4*(50*pow(10,-9))))*pow(10,-6)
print "fmax(ripple)(in MHz)=",fma,"MHz"
# Out:
# For asynchronous counter the total delay that must be allowed between input clock pulses is equal to flip−flop tpd+AND gate tpd.Thus Tclock>=50+20=70ns and so the counter has
# fmax(in MHz)= 14.3 MHz
# We know that MOD−16 ripple counter used four flip−flops. With flip−flop tpd=50ns,the fmax for ripple counter can be given as,
# fmax(ripple)(in MHz)= 5.0 MHz

# %% [markdown]
# ## Example 8.14 Page No. 8-25

# %%
print("IC74191 is a 4−bit counter.Thus it is MOD−16 counter.However,we require MOD−11 counter.The difference between 16 and 11 is 5.Hence 5 steps must be skipped from the full modulus sequence. This can be achieved by presetting counter to value 5.Each time when counter recycles it starts counting from 5 upto 16 on each full cycle.Therefore,each full cycle of the counter consists of 11 states.")
# Out:
# IC74191 is a 4−bit counter.Thus it is MOD−16 counter.However,we require MOD−11 counter.The difference between 16 and 11 is 5.Hence 5 steps must be skipped from the full modulus sequence. This can be achieved by presetting counter to value 5.Each time when counter recycles it starts counting from 5 upto 16 on each full cycle.Therefore,each full cycle of the counter consists of 11 states.

# %% [markdown]
# ## Example 8.15 Page No. 8-26

# %%
print("IC74191 is a 4−bit counter.Thus it is MOD−16 counter.However,we require MOD−10 counter.The difference between 16 and 10 is 6.Hence 6 steps must be skipped from the full modulus sequence. This can be achieved by presetting counter to value 6.Each time when counter recycles it starts counting from 6 upto 16 on each full cycle.Therefore,each full cycle of the counter consists of 10 states.")
# Out:
# IC74191 is a 4−bit counter.Thus it is MOD−16 counter.However,we require MOD−10 counter.The difference between 16 and 10 is 6.Hence 6 steps must be skipped from the full modulus sequence. This can be achieved by presetting counter to value 6.Each time when counter recycles it starts counting from 6 upto 16 on each full cycle.Therefore,each full cycle of the counter consists of 10 states.

# %% [markdown]
# ## Example 8.16 Page No. 8-26

# %%
print("The fig8.36 shows the connections for 74LS191 to get desire operation.We can design the combinational circuit for such counter from the truth table shown below.")
print("")
print("Q3Q2Q1Q0Y")
print("00000")
print("00010")
print("00100")
print("00111")
print("01001")
print("01011")
print("01101")
print("01111")
print("10001")
print("10011")
print("10101")
print("10111")
print("11001")
print("11011")
print("11100")
print("11110")
print("")
print("Kmap simplification")
print("Q1’’Q0’’Q1’’Q0Q1Q0Q1Q0’’")
print("Q3’’Q2’’0010")
print("Q3’’Q21111")
print("Q3Q21100")
print("Q3Q2’’1111")
print("")
print("Therefore,PL’’=Y=Q3’’Q1Q0+Q3’’Q2+Q3Q1’’+Q3Q2’’")
print("After switch ON,if the counter output is other than 1101 through 0011,the PL’’ goes low and count 1101 is loaded in the counter.The counter is then decremented on the occurrence of clock pulses.When counter reaches 0010,the PL’’ again goes low and count 1101 is loaded in the counter")
# Out:
# The fig8.36 shows the connections for 74LS191 to get desire operation.We can design the combinational circuit for such counter from the truth table shown below.
#
# Q3Q2Q1Q0Y
# 00000
# 00010
# 00100
# 00111
# 01001
# 01011
# 01101
# 01111
# 10001
# 10011
# 10101
# 10111
# 11001
# 11011
# 11100
# 11110
#
# Kmap simplification
# Q1’’Q0’’Q1’’Q0Q1Q0Q1Q0’’
# Q3’’Q2’’0010
# Q3’’Q21111
# Q3Q21100
# Q3Q2’’1111
#
# Therefore,PL’’=Y=Q3’’Q1Q0+Q3’’Q2+Q3Q1’’+Q3Q2’’
# After switch ON,if the counter output is other than 1101 through 0011,the PL’’ goes low and count 1101 is loaded in the counter.The counter is then decremented on the occurrence of clock pulses.When counter reaches 0010,the PL’’ again goes low and count 1101 is loaded in the counter

# %% [markdown]
# ## Example 8.17 Page No. 8-27

# %%
print("The IC74191 is a 4−bit binary counter, therefore fout=fCLK/16 in up and down counter mode.If fCLK=500Hz and fout=50Hz we need mod10(500/50)counter.The fig.8.39 shows the mod−10 counter using IC74191")
# Out:
# The IC74191 is a 4−bit binary counter, therefore fout=fCLK/16 in up and down counter mode.If fCLK=500Hz and fout=50Hz we need mod10(500/50)counter.The fig.8.39 shows the mod−10 counter using IC74191

# %% [markdown]
# ## Example 8.18 Page No. 8-28

# %%
print("The fig shows the connections for 74LS191 to get desire operation.We can design the combinational circuit for such counter from the truth table shown below.")
print("")
print("Q3Q2Q1Q0Y")
print("00000")
print("00010")
print("00100")
print("00111")
print("01001")
print("01011")
print("01101")
print("01111")
print("10001")
print("10011")
print("10101")
print("10111")
print("11001")
print("11011")
print("11101")
print("11110")
print("")
print("Kmap simplification")
print("Q1’’Q0’’Q1’’Q0Q1Q0Q1Q0’’")
print("Q3’’Q2’’0010")
print("Q3’’Q21111")
print("Q3Q21101")
print("Q3Q2’’1111")
print("")
print("Therefore,PL’’=Y=Q3’’Q1Q0+Q3’’Q2+Q3Q1’’+Q3Q2’’+Q2Q1Q0’’")
print("After switch ON,if the counter output is other than 1110 through 0011,the PL’’ goes low and count 1110 is loaded in the counter.The counter is then decremented on the occurrence of clock pulses.When counter reaches 0010,the PL’’ again goes low and count 1110 is loaded in the counter")
# Out:
# The fig shows the connections for 74LS191 to get desire operation.We can design the combinational circuit for such counter from the truth table shown below.
#
# Q3Q2Q1Q0Y
# 00000
# 00010
# 00100
# 00111
# 01001
# 01011
# 01101
# 01111
# 10001
# 10011
# 10101
# 10111
# 11001
# 11011
# 11101
# 11110
#
# Kmap simplification
# Q1’’Q0’’Q1’’Q0Q1Q0Q1Q0’’
# Q3’’Q2’’0010
# Q3’’Q21111
# Q3Q21101
# Q3Q2’’1111
#
# Therefore,PL’’=Y=Q3’’Q1Q0+Q3’’Q2+Q3Q1’’+Q3Q2’’+Q2Q1Q0’’
# After switch ON,if the counter output is other than 1110 through 0011,the PL’’ goes low and count 1110 is loaded in the counter.The counter is then decremented on the occurrence of clock pulses.When counter reaches 0010,the PL’’ again goes low and count 1110 is loaded in the counter

# %% [markdown]
# ## Example 8.19 Page No. 8-28

# %%
print("IC74191 is a 4−bit binary counter.Thus it divides the input frequency by 16.However,we can design MOD−N counter using IC74191.For MOD− N counter the output frequency will be fout= fin/N.Thus by changing N we can change the output frequency.The fig.8.40 shows the programmable frequncy divider using IC74191.")
# Out:
# IC74191 is a 4−bit binary counter.Thus it divides the input frequency by 16.However,we can design MOD−N counter using IC74191.For MOD− N counter the output frequency will be fout= fin/N.Thus by changing N we can change the output frequency.The fig.8.40 shows the programmable frequncy divider using IC74191.

# %% [markdown]
# ## Example 8.20 Page No. 8-28

# %%
print("Fig.8.41 shows Dividing−by−2 for up counting")
print("Divide−by−2 is a mod−2counter. Since,after preset above counter goes through 2 states 1110 and 1111,it is a mod−2counter.Thus,above circuit is a divide−by−2counter for up counting mode.")
print("")
print("Divide−by−5 for down counting mode:")
print("")
print("Q3Q2Q1Q0Y")
print("00000")
print("00010")
print("00100")
print("00110")
print("01000")
print("01010")
print("01100")
print("01110")
print("10000")
print("10010")
print("10100")
print("10111")
print("11001")
print("11011")
print("11101")
print("11111")
print("")
print("K=map simplification")
print("Q1’’Q0’’Q1’’Q0Q1Q0Q1Q0’’")
print("Q3’’Q2’’0000")
print("Q3’’Q20000")
print("Q3Q21111")
print("Q3Q2’’0010")
print("")
print("Therefore,Y = Q3Q2+Q3Q1Q0")
# Out:
# Fig.8.41 shows Dividing−by−2 for up counting
# Divide−by−2 is a mod−2counter. Since,after preset above counter goes through 2 states 1110 and 1111,it is a mod−2counter.Thus,above circuit is a divide−by−2counter for up counting mode.
#
# Divide−by−5 for down counting mode:
#
# Q3Q2Q1Q0Y
# 00000
# 00010
# 00100
# 00110
# 01000
# 01010
# 01100
# 01110
# 10000
# 10010
# 10100
# 10111
# 11001
# 11011
# 11101
# 11111
#
# K=map simplification
# Q1’’Q0’’Q1’’Q0Q1Q0Q1Q0’’
# Q3’’Q2’’0000
# Q3’’Q20000
# Q3Q21111
# Q3Q2’’0010
#
# Therefore,Y = Q3Q2+Q3Q1Q0

# %% [markdown]
# ## Example 8.21 Page No. 8-30

# %%
print("IC74191 is a 4−bit counter.Thus it is MOD−16 counter.However, we require MOD−9 counter.The difference between 16 and 9 is 7.Hence 7 steps must be skipped from the full modulus sequence. This can be achieved by presetting counter to value 7.Each time when counter recycles it starts counting from 7 upto 16 on each full cycle.Therefore,each fullcycle of the counter consists of 9 states.")
# Out:
# IC74191 is a 4−bit counter.Thus it is MOD−16 counter.However, we require MOD−9 counter.The difference between 16 and 9 is 7.Hence 7 steps must be skipped from the full modulus sequence. This can be achieved by presetting counter to value 7.Each time when counter recycles it starts counting from 7 upto 16 on each full cycle.Therefore,each fullcycle of the counter consists of 9 states.

# %% [markdown]
# ## Example 8.22 Page No. 8-32

# %%
print("Clock frequency = 256kHz")
print("Output frequency = 2kHz")
mn=256/2
print "Therefore, Modnumber = n = ",mn
print("Therefore,Counter is MOD−128 counter")
print("Mod−128 counter can count the numbers from 0 to 127.")
# Out:
# Clock frequency = 256kHz
# Output frequency = 2kHz
# Therefore, Modnumber = n =  128
# Therefore,Counter is MOD−128 counter
# Mod−128 counter can count the numbers from 0 to 127.

# %% [markdown]
# ## Example 8.23 Page No. 8-36

# %%
print("Internal structure of 7490 ripple counter IC is as shown in fig.8.50")
print("")
print("We know that,one IC can work as mod−10(BCD) counter.Therefore,we need two ICs.The counter will go through states 0−19 and should be reset on state 20 .i.e.")
print("QDQCQBQAQDQCQBQA")
print("00100000")
print("7490(2)7490(1)")
print("")
print("The diagram of divide−by−20 counter using IC7490 is as shown in fig.8.51")
# Out:
# Internal structure of 7490 ripple counter IC is as shown in fig.8.50
#
# We know that,one IC can work as mod−10(BCD) counter.Therefore,we need two ICs.The counter will go through states 0−19 and should be reset on state 20 .i.e.
# QDQCQBQAQDQCQBQA
# 00100000
# 7490(2)7490(1)
#
# The diagram of divide−by−20 counter using IC7490 is as shown in fig.8.51

# %% [markdown]
# ## Example 8.24 Page No. 8-37

# %%
print("IC7490 is a decade counter.When two such ICs are cascaded,it becomes a divide−by−100 counter.To get a divide−by−96 counter,the counter is reset as soon as it becomes 10010110.The diagram is shown in fig.8.52.")
# Out:
# IC7490 is a decade counter.When two such ICs are cascaded,it becomes a divide−by−100 counter.To get a divide−by−96 counter,the counter is reset as soon as it becomes 10010110.The diagram is shown in fig.8.52.

# %% [markdown]
# ## Example 8.25 Page No. 8-37

# %%
print("IC7490 is a decadecounter.When two such ICs are cascaded,it becomes a divide−by−100 counter. To get a divide−by−93counter,the counter is reset as soon as ot becomes 10010011.The diagram is as shown in fig.8.53")
# Out:
# IC7490 is a decadecounter.When two such ICs are cascaded,it becomes a divide−by−100 counter. To get a divide−by−93counter,the counter is reset as soon as ot becomes 10010011.The diagram is as shown in fig.8.53

# %% [markdown]
# ## Example 8.26 Page No. 8-38

# %%
print("IC7490 is a decade counter.When two such ICs are cascaded,it becomes a divide−by−100 counter.To get a divide by 78 or MOD−78 counter,the counter is reset as soon as ot becomes 01111000 as shown in fig.8.54")
# Out:
# IC7490 is a decade counter.When two such ICs are cascaded,it becomes a divide−by−100 counter.To get a divide by 78 or MOD−78 counter,the counter is reset as soon as ot becomes 01111000 as shown in fig.8.54

# %% [markdown]
# ## Example 8.28 Page No. 8-38

# %%
print("If the QD output is connected to A input of 7490IC and,input clock is applied to B input 100 divide by ten squarewave is obtained at output QA.")
print("Clock Outputs")
print("QAQDQCQB")
print("0LLLL")
print("1LLLH")
print("2LLHL")
print("3LLHH")
print("4LHLL")
print("5HLLL")
print("6HLLH")
print("7HLHL")
print("8HLHH")
print("9HHLL")
# Out:
# If the QD output is connected to A input of 7490IC and,input clock is applied to B input 100 divide by ten squarewave is obtained at output QA.
# Clock Outputs
# QAQDQCQB
# 0LLLL
# 1LLLH
# 2LLHL
# 3LLHH
# 4LHLL
# 5HLLL
# 6HLLH
# 7HLHL
# 8HLHH
# 9HHLL

# %% [markdown]
# ## Example 8.29 Page No. 8-39

# %%
print("IC 7490 is a decade counter. When two sunch ICs are cascaded, it becomes a divide-by-100 counter. To get a divide-by-25 counter, the counter is reset as soon as it becomes 0010 0101. The diagram is shown in Fig. 8.57.")
# Out:
# IC 7490 is a decade counter. When two sunch ICs are cascaded, it becomes a divide-by-100 counter. To get a divide-by-25 counter, the counter is reset as soon as it becomes 0010 0101. The diagram is shown in Fig. 8.57.

# %% [markdown]
# ## Example 8.31 Page No. 8-42

# %%
print("The fig.8.63 shows the cascaded connection of 4−bit binary counters.Let us see the circuit operation.ThecounterIC1operatesasacounter for countion in the UP direction since CLEAR = LOAD = 1.When the count reaches the maximum value(1111)its RC(Ripple Carry Output)goes HIGH which makes PandT(Enable)inputs of IC2 HIGH for one clockcycle advancing its output by 1 and making Q outputs of IC1,0 at the next clockcycle.After this clockcycle P=T=0 for IC2 and IC1 will go on counting the pulses.When the outputs of IC1 and IC2 both reach the maximum count,RC outputs of both of these ICs will go HIGH.This will make P=T of IC3 HIGH and therefore,in the next clockcycle IC3 count will be incrementeda nd simultaneously IC1 and IC2 will be cleared.This way the counting will continue.")
# Out:
# The fig.8.63 shows the cascaded connection of 4−bit binary counters.Let us see the circuit operation.ThecounterIC1operatesasacounter for countion in the UP direction since CLEAR = LOAD = 1.When the count reaches the maximum value(1111)its RC(Ripple Carry Output)goes HIGH which makes PandT(Enable)inputs of IC2 HIGH for one clockcycle advancing its output by 1 and making Q outputs of IC1,0 at the next clockcycle.After this clockcycle P=T=0 for IC2 and IC1 will go on counting the pulses.When the outputs of IC1 and IC2 both reach the maximum count,RC outputs of both of these ICs will go HIGH.This will make P=T of IC3 HIGH and therefore,in the next clockcycle IC3 count will be incrementeda nd simultaneously IC1 and IC2 will be cleared.This way the counting will continue.

# %% [markdown]
# ## Example 8.32 Page No. 8-44

# %%
print("Cascading four 74161(each 4−bit)counters we get 16(4x4) bit counter as shown in fig8.63.")
print("Therefore,we get 2ˆ16 = 65,536 modulus counter")
print("However,we require divide−by−40,000 counter.The difference between 65,536 and 40,000 is 25,536,which is the number of states those must be skipped from the full modulus sequence.This can be achieved by presetting the counting from 25,536 upto 65,536 on each fullcycle.Therefore, each fullcycle of the counter consists of 40,000 states.")
# Out:
# Cascading four 74161(each 4−bit)counters we get 16(4x4) bit counter as shown in fig8.63.
# Therefore,we get 2ˆ16 = 65,536 modulus counter
# However,we require divide−by−40,000 counter.The difference between 65,536 and 40,000 is 25,536,which is the number of states those must be skipped from the full modulus sequence.This can be achieved by presetting the counting from 25,536 upto 65,536 on each fullcycle.Therefore, each fullcycle of the counter consists of 40,000 states.

# %% [markdown]
# ## Example 8.33 Page No. 8-48

# %%
print("Although the 74X163 is a modulo−16 counter,it can be made to count in a modulus less than 16 by using the CLR’’or LD’’ input to shorten the normal counting sequence.The fig.8.69 shows circuit connections for modulo−11 counter.Here, load input is activated upon activation of RCO(ripple−carry−output).Since load input is adjusted to state 5,counter counts from 5 to 15 and then starts at 5 again,for a total of 11 states per counting cycle.")
print("")
print("We can also design modulo−11 counter using CLR’’ input as shown in fig.8.70.Here,NAND gate is used to detect state 10 and force the next state to 0. A2−input gate is used to detect state 10 (binary 1010)by connecting Q1 and Q3 to the inputs of the NAND gate.")
# Out:
# Although the 74X163 is a modulo−16 counter,it can be made to count in a modulus less than 16 by using the CLR’’or LD’’ input to shorten the normal counting sequence.The fig.8.69 shows circuit connections for modulo−11 counter.Here, load input is activated upon activation of RCO(ripple−carry−output).Since load input is adjusted to state 5,counter counts from 5 to 15 and then starts at 5 again,for a total of 11 states per counting cycle.
#
# We can also design modulo−11 counter using CLR’’ input as shown in fig.8.70.Here,NAND gate is used to detect state 10 and force the next state to 0. A2−input gate is used to detect state 10 (binary 1010)by connecting Q1 and Q3 to the inputs of the NAND gate.

# %% [markdown]
# ## Example 8.34 Page No. 8-49

# %%
print("An excess−3 decimal counter should start counting from count3(binary0011) and count upto count 12(binary1100).Starting count is adjusted by loading 0011 at load inputs.To recycle count from 1100 to 0011,Q3 and Q2 output are connected as inputs for 2−input NAND gate. Thus,NAND gate detects state 1100 and forces 0011 to be loaded as the next state.")
# Out:
# An excess−3 decimal counter should start counting from count3(binary0011) and count upto count 12(binary1100).Starting count is adjusted by loading 0011 at load inputs.To recycle count from 1100 to 0011,Q3 and Q2 output are connected as inputs for 2−input NAND gate. Thus,NAND gate detects state 1100 and forces 0011 to be loaded as the next state.

# %% [markdown]
# ## Example 8.35 Page No. 8-50

# %%
print("A binary counter with a modulus greater than 16 can be built by cascading 74X163s.When counters are cascaded,CLK,CLR’’and LD’’ of all the 74X163s are connected in parallel,so that all of them count or are cleared or loaded at the sametime.The RCO signal drives the ENT input of the next counter.The fig.8.73 shows modulo−60 counter.To have a modulo 60 count we need at least 6−bit counter,thus two 74X163s are cascaded.Counter is designed to count from 196 to 255.The MAXCNT signal detects the state 255 and stops the counter util GO’’is asserted.When GO’’ is asserted the counter is reloaded with 196(binary 11000100) and counts upto 255.To enable counting, CNTEN is connected to the ENP inputs in parallel.A NAND gate assets RELOAD’’ to get back to state only if GO’’ is asserted and the counter is in state 255.")
# Out:
# A binary counter with a modulus greater than 16 can be built by cascading 74X163s.When counters are cascaded,CLK,CLR’’and LD’’ of all the 74X163s are connected in parallel,so that all of them count or are cleared or loaded at the sametime.The RCO signal drives the ENT input of the next counter.The fig.8.73 shows modulo−60 counter.To have a modulo 60 count we need at least 6−bit counter,thus two 74X163s are cascaded.Counter is designed to count from 196 to 255.The MAXCNT signal detects the state 255 and stops the counter util GO’’is asserted.When GO’’ is asserted the counter is reloaded with 196(binary 11000100) and counts upto 255.To enable counting, CNTEN is connected to the ENP inputs in parallel.A NAND gate assets RELOAD’’ to get back to state only if GO’’ is asserted and the counter is in state 255.

# %% [markdown]
# ## Example 8.36 Page No. 8-50

# %%
print("A binary counter maybe combined with a decoder to obtain a set of 1−out−of−M coded signals,where one signal is asserted in each count state.This is useful when countersare used to control a set of devices,where a different devices is enabled in each counter state.")
print("The fig.8.74 shows a 74X163 connected as a modulo−8 counter can be combined with a 74X138 3−8 decoder to provide eight signals,each one representing a counter state.")
# Out:
# A binary counter maybe combined with a decoder to obtain a set of 1−out−of−M coded signals,where one signal is asserted in each count state.This is useful when countersare used to control a set of devices,where a different devices is enabled in each counter state.
# The fig.8.74 shows a 74X163 connected as a modulo−8 counter can be combined with a 74X138 3−8 decoder to provide eight signals,each one representing a counter state.

# %% [markdown]
# ## Example 8.37 Page No. 8-62

# %%
print("Excitation table")
print("PresentState NextState Flip−flop Inputs")
print("QDQCQBQAQD+1QC+1QB+1QA+1JKDJKCJKBJKA")
print("000000010001")
print("000100100011")
print("001000110001")
print("001101000111")
print("010001010001")
print("010101100011")
print("011001110001")
print("011110001111")
print("100010010001")
print("100100001001")
print("1010XXXXXXX1")
print("1011XXXXXXX1")
print("1100XXXXXXXX")
print("1101XXXXXXXX")
print("1110XXXXXXXX")
print("1111XXXXXXXX")
print("")
print("K−map Simplification")
print("For JKD")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’0000")
print("QD’’QC0010")
print("QDQCXXXX")
print("QDQC’’01XX")
print("JKD = QAQD+QAQBQC")
print("")
print("For JKC")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’0010")
print("QD’’QC0010")
print("QDQCXXXX")
print("QDQC’’00XX")
print("JKC = QAQB")
print("")
print("For JKB")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’0110")
print("QD’’QC0110")
print("QDQCXXXX")
print("QDQC’’00XX")
print("JKB = QAQD’’")
print("")
print("For JKA")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’1111")
print("QD’’QC1111")
print("QDQCXXXX")
print("QDQC’’11XX")
print("JKA = 1")
print("")
print("Fig shows the logic diagram for the synchronous decade counter using JK flip−flop")
# Out:
# Excitation table
# PresentState NextState Flip−flop Inputs
# QDQCQBQAQD+1QC+1QB+1QA+1JKDJKCJKBJKA
# 000000010001
# 000100100011
# 001000110001
# 001101000111
# 010001010001
# 010101100011
# 011001110001
# 011110001111
# 100010010001
# 100100001001
# 1010XXXXXXX1
# 1011XXXXXXX1
# 1100XXXXXXXX
# 1101XXXXXXXX
# 1110XXXXXXXX
# 1111XXXXXXXX
#
# K−map Simplification
# For JKD
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’0000
# QD’’QC0010
# QDQCXXXX
# QDQC’’01XX
# JKD = QAQD+QAQBQC
#
# For JKC
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’0010
# QD’’QC0010
# QDQCXXXX
# QDQC’’00XX
# JKC = QAQB
#
# For JKB
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’0110
# QD’’QC0110
# QDQCXXXX
# QDQC’’00XX
# JKB = QAQD’’
#
# For JKA
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’1111
# QD’’QC1111
# QDQCXXXX
# QDQC’’11XX
# JKA = 1
#
# Fig shows the logic diagram for the synchronous decade counter using JK flip−flop

# %% [markdown]
# ## Example 8.38 Page No. 8-64

# %%
print("Excitation table")
print("Input PresentState NextState Flip−flop Inputs")
print("UP/DOWN’’QCQBQAQC+1QB+1QA+1JKCJKBJKA")
print("UD")
print("0000111111")
print("0001000001")
print("0010001011")
print("0011010001")
print("0100011111")
print("0101100001")
print("0110101011")
print("0111110001")
print("1000001001")
print("1001010011")
print("1010011001")
print("1011100111")
print("1100101001")
print("1101110011")
print("1110111001")
print("1111000111")
print("")
print("K−map Simplification")
print("For JKC")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’1000")
print("QD’’QC1000")
print("QDQC0010")
print("QDQC’’0010")
print("JKC = UD’’QB’’QB’’+UDQBQA")
print("")
print("For JKB")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’1001")
print("QD’’QC1001")
print("QDQC0110")
print("QDQC’’0110")
print("TB = UD’’QA’’+UDQA")
print("")
print("For JKA")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’1111")
print("QD’’QC1111")
print("QDQC1111")
print("QDQC’’1111")
print("TA = 1")
print("")
# Out:
# Excitation table
# Input PresentState NextState Flip−flop Inputs
# UP/DOWN’’QCQBQAQC+1QB+1QA+1JKCJKBJKA
# UD
# 0000111111
# 0001000001
# 0010001011
# 0011010001
# 0100011111
# 0101100001
# 0110101011
# 0111110001
# 1000001001
# 1001010011
# 1010011001
# 1011100111
# 1100101001
# 1101110011
# 1110111001
# 1111000111
#
# K−map Simplification
# For JKC
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’1000
# QD’’QC1000
# QDQC0010
# QDQC’’0010
# JKC = UD’’QB’’QB’’+UDQBQA
#
# For JKB
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’1001
# QD’’QC1001
# QDQC0110
# QDQC’’0110
# TB = UD’’QA’’+UDQA
#
# For JKA
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’1111
# QD’’QC1111
# QDQC1111
# QDQC’’1111
# TA = 1

# %% [markdown]
# ## Example 8.39 Page No. 8-66

# %%
print("For mod−5 counter we require 3 flip−flops.")
print("Excitation table")
print("PresentState NextState Flip−flop Inputs")
print("QCQBQAQA+1QB+1QC+1TATBTC")
print("0000001001")
print("1001010011")
print("2010011001")
print("3011100111")
print("4100000100")
print("")
print("K−map Simplification")
print("QB’’QC’’QB’’QCQBQCQBQC’’")
print("QA’’0010")
print("QA1XXX")
print("TA = QA+QBQC")
print("")
print("QB’’QC’’QB’’QCQBQCQBQC’’")
print("QA’’0110")
print("QA0XXX")
print("TB = QC")
print("")
print("QB’’QC’’QB’’QCQBQCQBQC’’")
print("QA’’1111")
print("QA0XXX")
print("TC = QA’’")
print("")
# Out:
# For mod−5 counter we require 3 flip−flops.
# Excitation table
# PresentState NextState Flip−flop Inputs
# QCQBQAQA+1QB+1QC+1TATBTC
# 0000001001
# 1001010011
# 2010011001
# 3011100111
# 4100000100
#
# K−map Simplification
# QB’’QC’’QB’’QCQBQCQBQC’’
# QA’’0010
# QA1XXX
# TA = QA+QBQC
#
# QB’’QC’’QB’’QCQBQCQBQC’’
# QA’’0110
# QA0XXX
# TB = QC
#
# QB’’QC’’QB’’QCQBQCQBQC’’
# QA’’1111
# QA0XXX
# TC = QA’’

# %% [markdown]
# ## Example 8.40 Page No. 8-67

# %%
print("Excitation table")
print("PresentState NextState Flip−flop Inputs")
print("QCQBA+B+JAKAJBKB")
print("00111X1X")
print("01000XX1")
print("1001X11X")
print("1110X0X1")
print("")
print("K−map Simplification")
print("For JA")
print("B’’B")
print("A’’10")
print("AXX")
print("JA = B’’")
print("")
print("For KA")
print("B’’B")
print("A’’XX")
print("A10")
print("KA = B’’")
print("")
print("For JB")
print("B’’B")
print("A’’1X")
print("A1X")
print("JB = 1")
print("")
print("For KB")
print("B’’B")
print("A’’X1")
print("AX1")
print("KB = 1")
print("")
# Out:
# Excitation table
# PresentState NextState Flip−flop Inputs
# QCQBA+B+JAKAJBKB
# 00111X1X
# 01000XX1
# 1001X11X
# 1110X0X1
#
# K−map Simplification
# For JA
# B’’B
# A’’10
# AXX
# JA = B’’
#
# For KA
# B’’B
# A’’XX
# A10
# KA = B’’
#
# For JB
# B’’B
# A’’1X
# A1X
# JB = 1
#
# For KB
# B’’B
# A’’X1
# AX1
# KB = 1

# %% [markdown]
# ## Example 8.41 Page No. 8-67

# %%
print("Mod−12 synchronous counter using D flip−flop:")
print("Let Number of flip−flop required=n")
print("2ˆn >= 12")
print("n = 4")
print("Excitation table")
print("PresentState NextState")
print("QDQCQBQAQD+1QC+1QB+1QA+1")
print("00000001")
print("00010010")
print("00100011")
print("00110100")
print("01000101")
print("01010110")
print("01100111")
print("01111000")
print("10001001")
print("10011010")
print("10101011")
print("10110000")
print("")
print("K−map Simplification")
print("For DA")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’1001")
print("QD’’QC1001")
print("QDQCXXXX")
print("QDQC’’1001")
print("DA = QA’’")
print("")
print("For DB")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’0101")
print("QD’’QC0101")
print("QDQCXXXX")
print("QDQC’’0101")
print("DB = QB’’QaA+QA’’QB")
print("DB = QA XOR QB")
print("")
print("For DC")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’0010")
print("QD’’QC1101")
print("QDQCXXXX")
print("QDQC’’0000")
print("DC = QCQB’’+QCQA’’+QD’’QC’’QBQA")
print("")
print("For DD")
print("QB’’QA’’QB’’QAQBQAQBQA’’")
print("QD’’QC’’0000")
print("QD’’QC0010")
print("QDQCXXXX")
print("QDQC’’1101")
print("DD = QDQB’’+QCQBQA+QDQA’’")
# Out:
# Mod−12 synchronous counter using D flip−flop:
# Let Number of flip−flop required=n
# 2ˆn >= 12
# n = 4
# Excitation table
# PresentState NextState
# QDQCQBQAQD+1QC+1QB+1QA+1
# 00000001
# 00010010
# 00100011
# 00110100
# 01000101
# 01010110
# 01100111
# 01111000
# 10001001
# 10011010
# 10101011
# 10110000
#
# K−map Simplification
# For DA
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’1001
# QD’’QC1001
# QDQCXXXX
# QDQC’’1001
# DA = QA’’
#
# For DB
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’0101
# QD’’QC0101
# QDQCXXXX
# QDQC’’0101
# DB = QB’’QaA+QA’’QB
# DB = QA XOR QB
#
# For DC
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’0010
# QD’’QC1101
# QDQCXXXX
# QDQC’’0000
# DC = QCQB’’+QCQA’’+QD’’QC’’QBQA
#
# For DD
# QB’’QA’’QB’’QAQBQAQBQA’’
# QD’’QC’’0000
# QD’’QC0010
# QDQCXXXX
# QDQC’’1101
# DD = QDQB’’+QCQBQA+QDQA’’

# %% [markdown]
# ## Example 8.42 Page No. 8-71

# %%
print("The fig.8.99 shows the circuit diagram for a 4−bit,4−statering counter with a single circulating 1.Here,74X194 universal shift register is connected so that it normally preforms a left−shift.However,when RESET is asserted it loads 0001.Once RESET is negated, the 74194 shifts left on each clock pulse.The DSL serial input is connected to the leftmost output(Q3:MSB),so the next states are 0010, 0100,1000,0001,0010,.....Thus the counter counter visits four unique states before repeating.")
# Out:
# The fig.8.99 shows the circuit diagram for a 4−bit,4−statering counter with a single circulating 1.Here,74X194 universal shift register is connected so that it normally preforms a left−shift.However,when RESET is asserted it loads 0001.Once RESET is negated, the 74194 shifts left on each clock pulse.The DSL serial input is connected to the leftmost output(Q3:MSB),so the next states are 0010, 0100,1000,0001,0010,.....Thus the counter counter visits four unique states before repeating.

# %% [markdown]
# ## Example 8.44 Page No. 8-76

# %%
print("Johnson counter is basically at wistedring counter.The fig.8.104(a) shows the basic circuit for a Johnson counter.The table shows the states of a 4−bit Johnson counter.")
print("")
print("States of 4−bit Johnson counter")
print("Statename Q3 Q2 Q1 Q0")
print("S1 0 0 0 0")
print("S2 0 0 0 1")
print("S3 0 0 1 1")
print("S4 0 1 1 1")
print("S5 1 1 1 1")
print("S6 1 1 1 0")
print("S7 1 1 0 0")
print("S8 1 0 0 0")
print("")
print("This counter can be modified to have self correcting Johnson counter as shown in fig.8.104(c).Here,the connections are made such that circuit loads 0001 as the next state whenever the current state is 0XX0.")
# Out:
# Johnson counter is basically at wistedring counter.The fig.8.104(a) shows the basic circuit for a Johnson counter.The table shows the states of a 4−bit Johnson counter.
#
# States of 4−bit Johnson counter
# Statename Q3 Q2 Q1 Q0
# S1 0 0 0 0
# S2 0 0 0 1
# S3 0 0 1 1
# S4 0 1 1 1
# S5 1 1 1 1
# S6 1 1 1 0
# S7 1 1 0 0
# S8 1 0 0 0
#
# This counter can be modified to have self correcting Johnson counter as shown in fig.8.104(c).Here,the connections are made such that circuit loads 0001 as the next state whenever the current state is 0XX0.

# %% [markdown]
# ## Example 8.45 Page No. 8-78

# %%
print("Johnson counter will produce a modulus of 2xn where n is the number of stages (i.e. flip−flops) in the counter.Therefore, Mod10 requires 5 flip−flops and Mod16 requires 8 flip−flops.")
# Out:
# Johnson counter will produce a modulus of 2xn where n is the number of stages (i.e. flip−flops) in the counter.Therefore, Mod10 requires 5 flip−flops and Mod16 requires 8 flip−flops.
