# %% [markdown]
# # Chapter 02: Fundamentals of C language

# %% [markdown]
# ## Example 3, Page Number: CP-22

# %%
# variable declaration

a = 5
b = 7
c = 2

# calculation 

y = a + b / c - a % c + 2 * a

# result 

print "The result is ",y
# Out:
# The result is  17
