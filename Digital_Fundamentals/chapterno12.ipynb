# %% [markdown]
# # Chapter No 12:Programmable Logic Devices (PLDs)

# %% [markdown]
# ## Example NO:12-1, Page NO:510

# %%
print'The programmed array is shown in figure. The intact fusible links are inicated by small red Xs.The absence of an X means that the fuse has been blown.'
from IPython.display import Image
Image(filename='12-1.jpg')
# Out:
# The programmed array is shown in figure. The intact fusible links are inicated by small red Xs.The absence of an X means that the fuse has been blown.

# %% [markdown]
# ## Example NO:12-2, Page NO:513

# %%
print'(a)  12 inputs,6 Outputs,active-HIGH outputs.'
print'(b)  16 inputs,2 outputs, active-LOW outputs.'
print'(c)  20 inputs,8 outputs,programmable polarity outputs.'
# Out:
# (a)  12 inputs,6 Outputs,active-HIGH outputs.
# (b)  16 inputs,2 outputs, active-LOW outputs.
# (c)  20 inputs,8 outputs,programmable polarity outputs.

# %% [markdown]
# ## Example NO:12-3, Page NO:515

# %%
print'The programmed array using simplified notation is shown in Figure.Cells that are on are indicated by small red Xs.The absence of an X means that the cell is off.'
from IPython.display import Image
Image(filename='12-3.jpg')
# Out:
# The programmed array using simplified notation is shown in Figure.Cells that are on are indicated by small red Xs.The absence of an X means that the cell is off.

# %% [markdown]
# ## Example NO:12-4,Page NO:516

# %%
print'(a) 20 inputs, 8 Outputs.'
print'(b) 22 inputs, 10 Outputs.'
# Out:
# (a) 20 inputs, 8 Outputs.
# (b) 22 inputs, 10 Outputs.

# %% [markdown]
# ## Example NO:12-5, Page NO:525

# %%
print'The OLMC is configured for an active-HIGH combinational output;therefore,the SOP expression is:'
print"X=ABCD+A'BCD'+AB'CD'+A'BC'D+AB'CD+ABC'D."
# Out:
# The OLMC is configured for an active-HIGH combinational output;therefore,the SOP expression is:
# X=ABCD+A'BCD'+AB'CD'+A'BC'D+AB'CD+ABC'D.

# %% [markdown]
# ## Example NO:12-6,Page NO:527

# %%
print'The programmed portion of the array with the associated OLMC is shown in figure.The rest of the array remain unused in this case.The Xs represent E^2CMOS cells that are programmed to the on state.'
from IPython.display import Image
Image(filename='12-6.jpg')
# Out:
# The programmed portion of the array with the associated OLMC is shown in figure.The rest of the array remain unused in this case.The Xs represent E^2CMOS cells that are programmed to the on state.
