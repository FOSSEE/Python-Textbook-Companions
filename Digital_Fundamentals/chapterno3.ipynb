# %% [markdown]
# # Chapter NO 3: Logic Gates

# %% [markdown]
# ## Example NO:3-1,Page NO:80

# %%
print'The Output waveform is exactly opposite to the input(inverted),which is basic timig diagram.The active shed or asserted output state is 0.'
# Out:
# The Output waveform is exactly opposite to the input(inverted),which is basic timig diagram.The active shed or asserted output state is 0.

# %% [markdown]
# ## Example NO:3-2,Page NO:83

# %%
print'(a) There are eight possible input combinations (2^3=8) for a 3-input AND. The input side of the truth table shows all eight combinations of three bits. The output side is all 0s except when all three input bits are 1s.'
a="""<table>
<tr>
<th>INPUTS</th>
<th>OUTPUTS</th>
</tr>
<tr>
<td>ABC</td>
<td>X</td>
</tr>
<tr>
<td>000</td>
<td>0</td>
</tr>
<tr>
<td>001</td>
<td>0</td>
</tr><tr>
<td>010</td>
<td>0</td>
</tr><tr>
<td>01</td>
<td>0</td>
</tr><tr>
<td>100</td>
<td>0</td>
</tr><tr>
<td>101</td>
<td>0</td>
</tr><tr>
<td>110</td>
<td>0</td>
</tr><tr>
<td>111</td>
<td>1</td>
</tr>
</table>"""
# Out:
# (a) There are eight possible input combinations (2^3=8) for a 3-input AND. The input side of the truth table shows all eight combinations of three bits. The output side is all 0s except when all three input bits are 1s.

# %%
from IPython.display import HTML
h  =  HTML(a);h
# Out:
# <table>
# <tr>
# <th>INPUTS</th>
# <th>OUTPUTS</th>
# </tr>
# <tr>
# <td>ABC</td>
# <td>X</td>
# </tr>
# <tr>
# <td>000</td>
# <td>0</td>
# </tr>
# <tr>
# <td>001</td>
# <td>0</td>
# </tr><tr>
# <td>010</td>
# <td>0</td>
# </tr><tr>
# <td>01</td>
# <td>0</td>
# </tr><tr>
# <td>100</td>
# <td>0</td>
# </tr><tr>
# <td>101</td>
# <td>0</td>
# </tr><tr>
# <td>110</td>
# <td>0</td>
# </tr><tr>
# <td>111</td>
# <td>1</td>
# </tr>
# </table>

# %% [markdown]
# ## Example NO:3-3, Page NO:85

# %%
print'The output waveform X is HIGH only when both A and B waveforms are HIGH as shown in figure.'
from IPython.display import Image
Image(filename='3-3.jpg')
# Out:
# The output waveform X is HIGH only when both A and B waveforms are HIGH as shown in figure.

# %% [markdown]
# ## Example NO:3-4, Page NO:85

# %%
print'The oouput waveform is HIGH only when both of the input are HIgh.'
# Out:
# The oouput waveform is HIGH only when both of the input are HIgh.

# %% [markdown]
# ## Example NO:3-5, Page NO:86

# %%
print'The output waveform X of the 3-input AND gate is HIGH only when all three input waveforms A,B,and C are HIGH.'
# Out:
# The output waveform X of the 3-input AND gate is HIGH only when all three input waveforms A,B,and C are HIGH.

# %% [markdown]
# ## Example NO:3-6,Page NO:90

# %%
print'The output waveforms X of a 2-input OR gate is HIGH when either or both input waveforms are HIGH. In this case, both input waveforms are never HIGH at the same time.'
# Out:
# The output waveforms X of a 2-input OR gate is HIGH when either or both input waveforms are HIGH. In this case, both input waveforms are never HIGH at the same time.

# %% [markdown]
# ## Example NO:3-7,Page NO:90

# %%
print'When either or both input waveforms are HIGH,the output is HIGH.'
# Out:
# When either or both input waveforms are HIGH,the output is HIGH.

# %% [markdown]
# ## Example NO:3-8,Page NO:91

# %%
print'The output is HIGH when one or more of the input waveforms are HIGH as indicated by the output waveform X in the timing diagram.'
# Out:
# The output is HIGH when one or more of the input waveforms are HIGH as indicated by the output waveform X in the timing diagram.

# %% [markdown]
# ## Example NO:3-9,Page NO:94

# %%
print'Output waveform X is LOW only during the four time intervals when both input waveforms A and B are HIGH.'
# Out:
# Output waveform X is LOW only during the four time intervals when both input waveforms A and B are HIGH.

# %% [markdown]
# ## Example NO:3-10,Page NO:95

# %%
print'The Output waveform X is LOW only when all the three input waveforms are HIGH.'
# Out:
# The Output waveform X is LOW only when all the three input waveforms are HIGH.

# %% [markdown]
# ## Example NO:3-11, Page NO:96

# %%
print'As shown in figure shows a NAND gate with its two inputs connected to the tank level sensors and its output connected to the indicator panel.The operation can be stated as follows:If tank A ab=nd tank B are above one-quarter full,The LEDis on.'
print'As long as both sensor outputs are HIGH(5 V), indicating that both tanks are more than one-quarter full,the NAND gate output is LOW(0 V).The green LED circuit is arranged so that a LOW voltage turns it on.'
from IPython.display import Image
Image(filename='3-11.jpg')
# Out:
# As shown in figure shows a NAND gate with its two inputs connected to the tank level sensors and its output connected to the indicator panel.The operation can be stated as follows:If tank A ab=nd tank B are above one-quarter full,The LEDis on.
# As long as both sensor outputs are HIGH(5 V), indicating that both tanks are more than one-quarter full,the NAND gate output is LOW(0 V).The green LED circuit is arranged so that a LOW voltage turns it on.

# %% [markdown]
# ## Example NO:3-12,Page NO:96

# %%
print'Figure shows a NAND gate operating as a negative-OR gate to detect the occurence of at least one LOW on its inputs.A sensor puts out a LOW voltage if the volume in its tank goes to one-quarter full or less.When this happens,the gate output  goes HIGH.The red LED circuit in the panel is arranged so that a HIGH voltage turns it on.The operation can be stated as folows: If tank A and tank B or both are below one-quarter full,the LED is on.'
from IPython.display import Image
Image(filename='3-12.jpg')
# Out:
# Figure shows a NAND gate operating as a negative-OR gate to detect the occurence of at least one LOW on its inputs.A sensor puts out a LOW voltage if the volume in its tank goes to one-quarter full or less.When this happens,the gate output  goes HIGH.The red LED circuit in the panel is arranged so that a HIGH voltage turns it on.The operation can be stated as folows: If tank A and tank B or both are below one-quarter full,the LED is on.

# %% [markdown]
# ## Example NO:3-13,Page NO:97

# %%
print'The output waveform X is HIGH any time an input waveform is LOW.'
# Out:
# The output waveform X is HIGH any time an input waveform is LOW.

# %% [markdown]
# ## Example NO:3-14,Page NO:100

# %%
print'Whenever any input of the NOR gate is HIGH,the output is LOW.'
# Out:
# Whenever any input of the NOR gate is HIGH,the output is LOW.

# %% [markdown]
# ## Example NO:3-15,Page NO:100

# %%
print'The Output X is LOW when any input is HIGH.'
# Out:
# The Output X is LOW when any input is HIGH.

# %% [markdown]
# ## Example NO:3-16, Page NO:101

# %%
print'A NOR gate operating as a negative-AND gate is required to produce a HIGH output when both inputs are LOW.'
# Out:
# A NOR gate operating as a negative-AND gate is required to produce a HIGH output when both inputs are LOW.

# %% [markdown]
# ## Example NO:3-17, Page NO:101

# %%
print'Power is applied to the circuit only when the "gear down" switch is activatred.Use a NOR gate for each of the two requirements as shown in figure.One NOR gate operates as a negative-AND to detect a LOW from each of the three landing gear sensors.When all three of the gate inputs are LOW,the three landing gears are properly extended and the resulting HIGH output from the negative-AND gate turns on the green LED display.The other NOR gate operates as a NOR to detect if one or more of the landing gear remain retracted when the "gear down" switch is activated.When one or more of the landing gears remain retracted,the resulting HIGH from the sensor is detetcted by the NOR gate,which produces a LOW output to turn on the red LED warning display.'
from IPython.display import Image
Image(filename='3-17.jpg')
# Out:
# Power is applied to the circuit only when the "gear down" switch is activatred.Use a NOR gate for each of the two requirements as shown in figure.One NOR gate operates as a negative-AND to detect a LOW from each of the three landing gear sensors.When all three of the gate inputs are LOW,the three landing gears are properly extended and the resulting HIGH output from the negative-AND gate turns on the green LED display.The other NOR gate operates as a NOR to detect if one or more of the landing gear remain retracted when the "gear down" switch is activated.When one or more of the landing gears remain retracted,the resulting HIGH from the sensor is detetcted by the NOR gate,which produces a LOW output to turn on the red LED warning display.

# %% [markdown]
# ## Example NO:3-18,Page NO:102

# %%
print'Any time all of the input waveforms are LOW,the output is HIGH.'
# Out:
# Any time all of the input waveforms are LOW,the output is HIGH.

# %% [markdown]
# ## Example NO:3-19, Page NO:104

# %%
print'The output of the circuits are connected to the inputs of an XOR gate as shown in figure.A failure ineither one of the circuits  produces differing outputs,which cause the XOR inputs to be at opposite levels.This condition produces a HIGH on the output of the XOR gate, indicating a failure in one of the circuit.'
from IPython.display import Image
Image(filename='3-19.jpg')
# Out:
# The output of the circuits are connected to the inputs of an XOR gate as shown in figure.A failure ineither one of the circuits  produces differing outputs,which cause the XOR inputs to be at opposite levels.This condition produces a HIGH on the output of the XOR gate, indicating a failure in one of the circuit.

# %% [markdown]
# ## Example No:3-20, Page NO:106

# %%
print'The output waveforms are shown in figure .Notice that the XOR output is HIGH only when both inputs are at opposite levels.Notice that the XNOR output is HIGH only when both inputs are the same.'
from IPython.display import Image
Image(filename='3-20.jpg')
# Out:
# The output waveforms are shown in figure .Notice that the XOR output is HIGH only when both inputs are at opposite levels.Notice that the XNOR output is HIGH only when both inputs are the same.
