# %% [markdown]
# # Chapter NO 9: Shift Registers

# %% [markdown]
# ## Example NO:9-1, Page NO:359

# %%
print'The first data bit(1) iis entered into the register on the first clock pulse and then shifted from left to right as the remaining bits are entered and shifted.The register contains Q4Q3Q2Q1Q0=11010 after five clock pulses. See figure part b.'
from IPython.display import Image
Image(filename='9-1.jpg')
# Out:
# The first data bit(1) iis entered into the register on the first clock pulse and then shifted from left to right as the remaining bits are entered and shifted.The register contains Q4Q3Q2Q1Q0=11010 after five clock pulses. See figure part b.

# %% [markdown]
# ## Example NO:9-2, Page NO:361

# %%
print'The register contains 0110 after four clock pulses. See figure part b.'
from IPython.display import Image
Image(filename='9-2.jpg')
# Out:
# The register contains 0110 after four clock pulses. See figure part b.

# %% [markdown]
# ## Example NO:9-3, Page NO:364

# %%
print'On clock pulse 1,the parallel data (D0D1D2D3=1010) are loaded into the register, making Q3 as 0.On clock pulse 2 the 1 from Q2 is shifted onto Q3;on clock pulse 3 the 0 is shifted onto Q3; on clock pulse 4 the last bit (1) is shifted onto Q3; and on clock pulse 5,all data bits have beenn shifted out, and only 1s remain in the register(assuming the D input remains a1). See figure part b.'
from IPython.display import Image
Image(filename='9-3.jpg')
# Out:
# On clock pulse 1,the parallel data (D0D1D2D3=1010) are loaded into the register, making Q3 as 0.On clock pulse 2 the 1 from Q2 is shifted onto Q3;on clock pulse 3 the 0 is shifted onto Q3; on clock pulse 4 the last bit (1) is shifted onto Q3; and on clock pulse 5,all data bits have beenn shifted out, and only 1s remain in the register(assuming the D input remains a1). See figure part b.

# %% [markdown]
# ## Example NO:9-4, Page NO:369

# %%
print"See figure part b"
from IPython.display import Image
Image(filename='9-4.jpg')
# Out:
# See figure part b

# %% [markdown]
# ## Example NO:9-5,Page NO:374

# %%
print'See figure part b'
from IPython.display import Image
Image(filename='9-5.jpg')
# Out:
# See figure part b

# %% [markdown]
# ## Example NO:9-6, Page NO:376

# %%
print'The clock period is 2*10**-6 sec. Thus, the time delay can be increased or decreased in 2*10**-6 increments from a minimum of 2*10**-6 sec to a maintain of 16*10**-6 sec, as illustrated in figure.'
from IPython.display import Image
Image(filename='9-6.jpg')
# Out:
# The clock period is 2*10**-6 sec. Thus, the time delay can be increased or decreased in 2*10**-6 increments from a minimum of 2*10**-6 sec to a maintain of 16*10**-6 sec, as illustrated in figure.
