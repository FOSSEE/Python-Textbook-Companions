# %% [markdown]
# <h1>Chapter 18: Programmable Analog Arrays<h1>

# %% [markdown]
# <h3>Example 18.1, Page Number: 588<h3>

# %%
import math#Variable declarationC=1000*10**-12;    #Switche capacitor value in faradsR=1000;            #resistance in ohms#calculationT=R*C;    #Time periodf=1/T;    #Frequency at which switch should operatef=math.ceil(f)#Resultprint('Frequency at which each switch should operate(in hertz) is \n %d' %f)print('Duty cycle should be 50%')
# Out:
# Frequency at which each switch should operate(in hertz) is  1000000Duty cycle should be 50%
