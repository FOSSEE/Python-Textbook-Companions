# %% [markdown]
# # Chapter 15: Debugging and optimization

# %% [markdown]
# ### Example 15.1, Page number: 275

# %%
# Example 15.1.py
# A database program to look up names in a hardcoded list


# Function declaration
def lookup (name) :
   lists = ['John', 'Jim', 'Jane', 'Clyde']
   result = 0

   for index in range (0, 4) :
      if (lists[index] == name) :
         result = 1
         break
   
   return result

# Calculation and result
name = 'John'

if (lookup (name)) :
   print ('%s is in the list\n' % name)
else :
   print ('%s is not in the list\n' % name)
# Out:
# John is in the list

# %% [markdown]
# ### Example 15.6, Page number: 288

# %%
# Example 15.6.py
# To count the number of 3's and 7's in an array


# Variable and function declaration
seven_count = 0
three_count = 0
data = []

def get_data (data) :
   for i in range (0, 5) :
      x = 3
      data.append(int(x))
   print (data)

# Calculation
get_data (data)
for index in range (0, 5) :
   if data[index] == 3 :
      three_count += 1

   if data[index] == 7 :
      seven_count += 1

# Result
print ('Threes %d Sevens %d' % (three_count, seven_count))
# Out:
# [3, 3, 3, 3, 3]
# Threes 5 Sevens 0

# %% [markdown]
# ### Example 15.7, Page number: 292

# %%
# Example 15.7.py
# To perform binary search on a number in a file 'numbers.dat'


# Variable declaration
import sys
import os
in_file = open ('numbers.dat', 'r')

data = []
max_count = 0
 
# Calculation and result
if not os.path.exists ('numbers.dat') :
   print ('Error:Unable to open numbers.dat\n')
   sys.exit(1)

for line in in_file :
   data.append(line)
   max_count += 1

while (1) :
   search = 6
   
   if (search == -1) :
      break

   low = 0
   high = max_count

   while (1) :
      mid = (low + high) / 2
      middle = int (mid)      

      if (int (data[middle]) == search) :
         print ('Found at index %d\n' % (middle + 1))
         break

      if (low == high) :
         print ('Not found\n')
         break

      if (int (data[middle]) < search) :
         low = middle
      else :
         high = middle      

in_file.close()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-ce867c3a4ec5> in <module>()
#       6 import sys
#       7 import os
# ----> 8 in_file = open ('numbers.dat', 'r')
#       9
#      10 data = []
#
# IOError: [Errno 2] No such file or directory: 'numbers.dat'

# %% [markdown]
# ### Example 15.8, Page number: 300

# %%
# Example 15.8.py
# To perform binary search on a number in a file 'numbers.dat'


# Variable declaration
import sys
import os
in_file = open ('numbers.dat', 'r')

data = []
max_count = 0
 
# Calculation and result
if not os.path.exists ('numbers.dat') :
   print ('Error:Unable to open numbers.dat\n')
   sys.exit(1)

for line in in_file :
   data.append(line)
   max_count += 1

while (1) :
   search = 14
   
   if (search == -1) :
      break

   low = 0
   high = max_count

   while (1) :
      mid = (low + high) / 2
      middle = int (mid)      

      if (int (data[middle]) == search) :
         print ('Found at index %d\n' % (middle + 1))
         break

      if (low == high) :
         print ('Not found\n')
         break

      if (int (data[middle]) < search) :
         low = middle
      else :
         high = middle      

in_file.close()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-8cd3b79f72a3> in <module>()
#       6 import sys
#       7 import os
# ----> 8 in_file = open ('numbers.dat', 'r')
#       9
#      10 data = []
#
# IOError: [Errno 2] No such file or directory: 'numbers.dat'

# %% [markdown]
# ### Example 15.10, Page number: 304

# %%
# Example 15.10.py
# To illustrate divide by zero error


# Variable declaration
i = 1
j = 0

# Calculation and result
print ('Starting\n')
print ('Before divide...')
i = i / j
print ('After\n')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-289ff2a55d4d> in <module>()
#      10 print ('Starting\n')
#      11 print ('Before divide...')
# ---> 12 i = i / j
#      13 print ('After\n')
#
# ZeroDivisionError: integer division or modulo by zero
# Starting
#
# Before divide...

# %% [markdown]
# ### Example 15.11, Page number: 304

# %%
# Example 15.11.py
# To illustrate divide by zero error with flush() function


# Variable declaration
import sys
i = 1
j = 0

# Calculation and result
print ('Starting\n')
sys.stdout.flush()
print ('Before divide...')
sys.stdout.flush()
i = i / j
print ('After\n')
sys.stdout.flush()
# Out:
# Starting
# Before divide...
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-eedd2fda3e82> in <module>()
#      13 print ('Before divide...')
#      14 sys.stdout.flush()
# ---> 15 i = i / j
#      16 print ('After\n')
#      17 sys.stdout.flush()
#
# ZeroDivisionError: integer division or modulo by zero
